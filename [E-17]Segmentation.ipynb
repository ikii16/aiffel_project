# %% [markdown]
# # 난 스케치를 할 테니 너는 채색을 하거라
# ## 프로젝트 : Segmentation map으로 도로 이미지 만들기
#
# 학습 목표
#
# 조건을 부여하여 생성 모델을 다루는 방법에 대해 이해합니다.
#
# cGAN 및 Pix2Pix의 구조와 학습 방법을 이해하고 잘 활용합니다.
#
# CNN 기반의 모델을 구현하는데 자신감을 갖습니다.

# %% [markdown]
# ### 데이터 준비하기

# %% [markdown]
# Cloud Shell에서 아래 명령어를 입력하여 사용할 zip 파일 압축 해제
#
# $ mkdir -p ~/aiffel/conditional_generation/data
#
# $ ln -s ~/data/cityscapes.zip ~/aiffel/conditional_generation/data
#
# $ cd ~/aiffel/conditional_generation/data && unzip cityscapes.zip

# %%
import numpy
import tensorflow
from tensorflow.keras import *

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지를 하나 열어 아래와 같이 크기를 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ### Generator 구현하기

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ### Discriminator 구현하기

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
# 각 출력의 크기가 맞는지 확인
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# 임의의 (256,256,3) 크기의 입력을 넣어 나오는 (30,30) 출력을 시각화
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ### 학습 및 테스트하기

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 50

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:2.1863
# L1_loss:0.2477
# Discriminator_loss:0.7481
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.7250
# L1_loss:0.2685
# Discriminator_loss:0.3774
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.2061
# L1_loss:0.2023
# Discriminator_loss:0.6124
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.3057
# L1_loss:0.2534
# Discriminator_loss:0.6524
#
# EPOCH[3] - STEP[100]
# Generator_loss:3.0209
# L1_loss:0.2266
# Discriminator_loss:0.3657
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.2772
# L1_loss:0.2117
# Discriminator_loss:0.6212
#
# EPOCH[4] - STEP[100]
# Generator_loss:0.7647
# L1_loss:0.2328
# Discriminator_loss:1.0699
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.0875
# L1_loss:0.2189
# Discriminator_loss:0.6103
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.6626
# L1_loss:0.1811
# Discriminator_loss:0.6438
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.6638
# L1_loss:0.1957
# Discriminator_loss:0.6848
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.9585
# L1_loss:0.2333
# Discriminator_loss:0.2964
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.3586
# L1_loss:0.2715
# Discriminator_loss:0.5831
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.6410
# L1_loss:0.2005
# Discriminator_loss:0.3885
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.5854
# L1_loss:0.1952
# Discriminator_loss:0.5409
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.8702
# L1_loss:0.2035
# Discriminator_loss:0.3782
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.4132
# L1_loss:0.1683
# Discriminator_loss:1.3787
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.0483
# L1_loss:0.1928
# Discriminator_loss:0.6681
#
# EPOCH[9] - STEP[200]
# Generator_loss:3.1534
# L1_loss:0.1917
# Discriminator_loss:0.6372
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.1287
# L1_loss:0.1742
# Discriminator_loss:0.5578
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.5522
# L1_loss:0.1850
# Discriminator_loss:0.7812
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.1373
# L1_loss:0.1387
# Discriminator_loss:1.8421
#
# EPOCH[11] - STEP[200]
# Generator_loss:0.6894
# L1_loss:0.1831
# Discriminator_loss:0.9164
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.0589
# L1_loss:0.1635
# Discriminator_loss:0.6896
#
# EPOCH[12] - STEP[200]
# Generator_loss:0.9202
# L1_loss:0.1570
# Discriminator_loss:0.9378
#
# EPOCH[13] - STEP[100]
# Generator_loss:0.6030
# L1_loss:0.1481
# Discriminator_loss:1.1024
#
# EPOCH[13] - STEP[200]
# Generator_loss:0.8435
# L1_loss:0.1606
# Discriminator_loss:1.1575
#
# EPOCH[14] - STEP[100]
# Generator_loss:2.1375
# L1_loss:0.1610
# Discriminator_loss:0.3627
#
# EPOCH[14] - STEP[200]
# Generator_loss:3.7541
# L1_loss:0.1424
# Discriminator_loss:0.8837
#
# EPOCH[15] - STEP[100]
# Generator_loss:0.4417
# L1_loss:0.1551
# Discriminator_loss:1.5303
#
# EPOCH[15] - STEP[200]
# Generator_loss:1.4617
# L1_loss:0.1723
# Discriminator_loss:0.6268
#
# EPOCH[16] - STEP[100]
# Generator_loss:2.6081
# L1_loss:0.1552
# Discriminator_loss:0.4501
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.3695
# L1_loss:0.1403
# Discriminator_loss:0.9137
#
# EPOCH[17] - STEP[100]
# Generator_loss:3.4483
# L1_loss:0.1649
# Discriminator_loss:0.7706
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.7466
# L1_loss:0.1871
# Discriminator_loss:0.6505
#
# EPOCH[18] - STEP[100]
# Generator_loss:3.3100
# L1_loss:0.1538
# Discriminator_loss:0.9291
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.4359
# L1_loss:0.1519
# Discriminator_loss:0.4798
#
# EPOCH[19] - STEP[100]
# Generator_loss:5.5318
# L1_loss:0.1846
# Discriminator_loss:2.1785
#
# EPOCH[19] - STEP[200]
# Generator_loss:1.1344
# L1_loss:0.1841
# Discriminator_loss:0.6397
#
# EPOCH[20] - STEP[100]
# Generator_loss:1.1954
# L1_loss:0.1297
# Discriminator_loss:0.8545
#
# EPOCH[20] - STEP[200]
# Generator_loss:2.9735
# L1_loss:0.2287
# Discriminator_loss:0.1863
#
# EPOCH[21] - STEP[100]
# Generator_loss:1.3149
# L1_loss:0.1687
# Discriminator_loss:0.6548
#
# EPOCH[21] - STEP[200]
# Generator_loss:2.0906
# L1_loss:0.1574
# Discriminator_loss:0.7936
#
# EPOCH[22] - STEP[100]
# Generator_loss:2.3166
# L1_loss:0.1605
# Discriminator_loss:0.4178
#
# EPOCH[22] - STEP[200]
# Generator_loss:3.9316
# L1_loss:0.1432
# Discriminator_loss:0.6744
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.6648
# L1_loss:0.1675
# Discriminator_loss:0.4090
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.6183
# L1_loss:0.1833
# Discriminator_loss:0.2180
#
# EPOCH[24] - STEP[100]
# Generator_loss:2.3031
# L1_loss:0.1375
# Discriminator_loss:0.3838
#
# EPOCH[24] - STEP[200]
# Generator_loss:2.3930
# L1_loss:0.1180
# Discriminator_loss:1.3280
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.7546
# L1_loss:0.1232
# Discriminator_loss:1.1296
#
# EPOCH[25] - STEP[200]
# Generator_loss:0.6912
# L1_loss:0.1988
# Discriminator_loss:0.9460
#
# EPOCH[26] - STEP[100]
# Generator_loss:2.6559
# L1_loss:0.1772
# Discriminator_loss:0.1293
#
# EPOCH[26] - STEP[200]
# Generator_loss:1.0931
# L1_loss:0.1795
# Discriminator_loss:0.8217
#
# EPOCH[27] - STEP[100]
# Generator_loss:2.3610
# L1_loss:0.1378
# Discriminator_loss:0.6938
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.6567
# L1_loss:0.1537
# Discriminator_loss:0.6748
#
# EPOCH[28] - STEP[100]
# Generator_loss:1.7245
# L1_loss:0.1638
# Discriminator_loss:0.4053
#
# EPOCH[28] - STEP[200]
# Generator_loss:2.2707
# L1_loss:0.1652
# Discriminator_loss:0.2219
#
# EPOCH[29] - STEP[100]
# Generator_loss:2.7711
# L1_loss:0.1793
# Discriminator_loss:0.1390
#
# EPOCH[29] - STEP[200]
# Generator_loss:1.0735
# L1_loss:0.1765
# Discriminator_loss:0.5436
#
# EPOCH[30] - STEP[100]
# Generator_loss:1.5780
# L1_loss:0.1439
# Discriminator_loss:0.4554
#
# EPOCH[30] - STEP[200]
# Generator_loss:2.4638
# L1_loss:0.1495
# Discriminator_loss:0.2802
#
# EPOCH[31] - STEP[100]
# Generator_loss:2.4243
# L1_loss:0.1367
# Discriminator_loss:0.5791
#
# EPOCH[31] - STEP[200]
# Generator_loss:4.5159
# L1_loss:0.1798
# Discriminator_loss:0.3157
#
# EPOCH[32] - STEP[100]
# Generator_loss:2.6280
# L1_loss:0.1673
# Discriminator_loss:0.6236
#
# EPOCH[32] - STEP[200]
# Generator_loss:2.4988
# L1_loss:0.1712
# Discriminator_loss:0.6422
#
# EPOCH[33] - STEP[100]
# Generator_loss:2.7211
# L1_loss:0.1626
# Discriminator_loss:0.6700
#
# EPOCH[33] - STEP[200]
# Generator_loss:0.3565
# L1_loss:0.1771
# Discriminator_loss:1.6327
#
# EPOCH[34] - STEP[100]
# Generator_loss:2.3694
# L1_loss:0.1312
# Discriminator_loss:0.5991
#
# EPOCH[34] - STEP[200]
# Generator_loss:4.0436
# L1_loss:0.1502
# Discriminator_loss:0.7787
#
# EPOCH[35] - STEP[100]
# Generator_loss:2.5818
# L1_loss:0.1827
# Discriminator_loss:1.3780
#
# EPOCH[35] - STEP[200]
# Generator_loss:2.5377
# L1_loss:0.1335
# Discriminator_loss:2.3694
#
# EPOCH[36] - STEP[100]
# Generator_loss:3.3507
# L1_loss:0.1463
# Discriminator_loss:0.4266
#
# EPOCH[36] - STEP[200]
# Generator_loss:3.4167
# L1_loss:0.1240
# Discriminator_loss:1.5817
#
# EPOCH[37] - STEP[100]
# Generator_loss:1.9149
# L1_loss:0.1198
# Discriminator_loss:0.5249
#
# EPOCH[37] - STEP[200]
# Generator_loss:1.5904
# L1_loss:0.1356
# Discriminator_loss:0.4876
#
# EPOCH[38] - STEP[100]
# Generator_loss:4.5455
# L1_loss:0.1710
# Discriminator_loss:0.6892
#
# EPOCH[38] - STEP[200]
# Generator_loss:2.5770
# L1_loss:0.1670
# Discriminator_loss:0.2744
#
# EPOCH[39] - STEP[100]
# Generator_loss:2.6121
# L1_loss:0.1496
# Discriminator_loss:0.2677
#
# EPOCH[39] - STEP[200]
# Generator_loss:1.0217
# L1_loss:0.1292
# Discriminator_loss:0.9266
#
# EPOCH[40] - STEP[100]
# Generator_loss:1.3389
# L1_loss:0.1409
# Discriminator_loss:0.9794
#
# EPOCH[40] - STEP[200]
# Generator_loss:3.9429
# L1_loss:0.1255
# Discriminator_loss:0.6835
#
# EPOCH[41] - STEP[100]
# Generator_loss:1.3895
# L1_loss:0.1308
# Discriminator_loss:0.5306
#
# EPOCH[41] - STEP[200]
# Generator_loss:4.0969
# L1_loss:0.1232
# Discriminator_loss:0.7760
#
# EPOCH[42] - STEP[100]
# Generator_loss:2.6738
# L1_loss:0.1329
# Discriminator_loss:0.1277
#
# EPOCH[42] - STEP[200]
# Generator_loss:1.6722
# L1_loss:0.1868
# Discriminator_loss:0.4490
#
# EPOCH[43] - STEP[100]
# Generator_loss:0.5810
# L1_loss:0.1447
# Discriminator_loss:1.1553
#
# EPOCH[43] - STEP[200]
# Generator_loss:2.3552
# L1_loss:0.1802
# Discriminator_loss:0.1584
#
# EPOCH[44] - STEP[100]
# Generator_loss:2.8811
# L1_loss:0.1274
# Discriminator_loss:3.2355
#
# EPOCH[44] - STEP[200]
# Generator_loss:3.6897
# L1_loss:0.1306
# Discriminator_loss:0.6042
#
# EPOCH[45] - STEP[100]
# Generator_loss:1.1798
# L1_loss:0.1374
# Discriminator_loss:0.6181
#
# EPOCH[45] - STEP[200]
# Generator_loss:2.1025
# L1_loss:0.1769
# Discriminator_loss:0.2639
#
# EPOCH[46] - STEP[100]
# Generator_loss:1.2650
# L1_loss:0.1512
# Discriminator_loss:0.5153
#
# EPOCH[46] - STEP[200]
# Generator_loss:3.8273
# L1_loss:0.1351
# Discriminator_loss:0.1418
#
# EPOCH[47] - STEP[100]
# Generator_loss:1.3252
# L1_loss:0.1371
# Discriminator_loss:0.7168
#
# EPOCH[47] - STEP[200]
# Generator_loss:3.9142
# L1_loss:0.1582
# Discriminator_loss:0.0770
#
# EPOCH[48] - STEP[100]
# Generator_loss:4.0780
# L1_loss:0.1359
# Discriminator_loss:0.5976
#
# EPOCH[48] - STEP[200]
# Generator_loss:1.4396
# L1_loss:0.1419
# Discriminator_loss:0.6120
#
# EPOCH[49] - STEP[100]
# Generator_loss:3.8148
# L1_loss:0.1474
# Discriminator_loss:0.1865
#
# EPOCH[49] - STEP[200]
# Generator_loss:3.1592
# L1_loss:0.1654
# Discriminator_loss:0.1883
#
# EPOCH[50] - STEP[100]
# Generator_loss:2.9594
# L1_loss:0.1260
# Discriminator_loss:0.2084
#
# EPOCH[50] - STEP[200]
# Generator_loss:3.3837
# L1_loss:0.1267
# Discriminator_loss:0.2583

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %%
EPOCHS = 100

generator2 = UNetGenerator()
discriminator2 = Discriminator()
history = {'gen_loss':[], 'l1_loss':[], 'disc_loss':[]}

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss2, l1_loss2, d_loss2 = train_step(sketch, colored)
        history['gen_loss'].append(g_loss2)
        history['l1_loss'].append(l1_loss2)
        history['disc_loss'].append(d_loss2)
        
        # 반복마다 손실을 출력합니다.
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss2.numpy():.4f} \
                    \nL1_loss:{l1_loss2.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss2.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:4.6042
# L1_loss:0.1559
# Discriminator_loss:0.2315
#
# EPOCH[1] - STEP[200]
# Generator_loss:4.5897
# L1_loss:0.1355
# Discriminator_loss:0.5732
#
# EPOCH[2] - STEP[100]
# Generator_loss:3.2744
# L1_loss:0.1344
# Discriminator_loss:0.3122
#
# EPOCH[2] - STEP[200]
# Generator_loss:4.9268
# L1_loss:0.1618
# Discriminator_loss:1.7423
#
# EPOCH[3] - STEP[100]
# Generator_loss:4.3501
# L1_loss:0.1326
# Discriminator_loss:0.3630
#
# EPOCH[3] - STEP[200]
# Generator_loss:6.2840
# L1_loss:0.1444
# Discriminator_loss:0.6142
#
# EPOCH[4] - STEP[100]
# Generator_loss:4.7466
# L1_loss:0.1729
# Discriminator_loss:0.2823
#
# EPOCH[4] - STEP[200]
# Generator_loss:0.9450
# L1_loss:0.1196
# Discriminator_loss:0.7580
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.9210
# L1_loss:0.1547
# Discriminator_loss:0.1397
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.8560
# L1_loss:0.1583
# Discriminator_loss:0.4928
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.6426
# L1_loss:0.1249
# Discriminator_loss:0.1612
#
# EPOCH[6] - STEP[200]
# Generator_loss:4.3370
# L1_loss:0.1213
# Discriminator_loss:0.8242
#
# EPOCH[7] - STEP[100]
# Generator_loss:4.1768
# L1_loss:0.1336
# Discriminator_loss:0.7724
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.3493
# L1_loss:0.1267
# Discriminator_loss:0.1787
#
# EPOCH[8] - STEP[100]
# Generator_loss:5.4335
# L1_loss:0.1411
# Discriminator_loss:1.5069
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.9328
# L1_loss:0.1581
# Discriminator_loss:0.8670
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.1458
# L1_loss:0.1276
# Discriminator_loss:0.2611
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.9616
# L1_loss:0.1407
# Discriminator_loss:0.7385
#
# EPOCH[10] - STEP[100]
# Generator_loss:5.8482
# L1_loss:0.1321
# Discriminator_loss:0.9280
#
# EPOCH[10] - STEP[200]
# Generator_loss:4.8846
# L1_loss:0.1463
# Discriminator_loss:0.4800
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.4743
# L1_loss:0.1662
# Discriminator_loss:0.1605
#
# EPOCH[11] - STEP[200]
# Generator_loss:3.6406
# L1_loss:0.1654
# Discriminator_loss:0.6564
#
# EPOCH[12] - STEP[100]
# Generator_loss:4.2376
# L1_loss:0.1445
# Discriminator_loss:0.7228
#
# EPOCH[12] - STEP[200]
# Generator_loss:3.2529
# L1_loss:0.1231
# Discriminator_loss:0.8921
#
# EPOCH[13] - STEP[100]
# Generator_loss:3.8746
# L1_loss:0.1354
# Discriminator_loss:0.1207
#
# EPOCH[13] - STEP[200]
# Generator_loss:5.3744
# L1_loss:0.1563
# Discriminator_loss:0.4254
#
# EPOCH[14] - STEP[100]
# Generator_loss:3.9564
# L1_loss:0.1334
# Discriminator_loss:0.7038
#
# EPOCH[14] - STEP[200]
# Generator_loss:2.2879
# L1_loss:0.1463
# Discriminator_loss:0.6783
#
# EPOCH[15] - STEP[100]
# Generator_loss:3.3751
# L1_loss:0.1104
# Discriminator_loss:0.2662
#
# EPOCH[15] - STEP[200]
# Generator_loss:1.7581
# L1_loss:0.2030
# Discriminator_loss:0.3879
#
# EPOCH[16] - STEP[100]
# Generator_loss:4.4737
# L1_loss:0.1425
# Discriminator_loss:0.3948
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.9432
# L1_loss:0.1403
# Discriminator_loss:0.4193
#
# EPOCH[17] - STEP[100]
# Generator_loss:3.8611
# L1_loss:0.1572
# Discriminator_loss:0.1387
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.0829
# L1_loss:0.1899
# Discriminator_loss:1.1501
#
# EPOCH[18] - STEP[100]
# Generator_loss:2.7263
# L1_loss:0.1352
# Discriminator_loss:0.1749
#
# EPOCH[18] - STEP[200]
# Generator_loss:2.3674
# L1_loss:0.1563
# Discriminator_loss:0.2641
#
# EPOCH[19] - STEP[100]
# Generator_loss:3.0060
# L1_loss:0.1347
# Discriminator_loss:0.1990
#
# EPOCH[19] - STEP[200]
# Generator_loss:0.9356
# L1_loss:0.1138
# Discriminator_loss:0.9364
#
# EPOCH[20] - STEP[100]
# Generator_loss:4.9395
# L1_loss:0.1539
# Discriminator_loss:1.5611
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.7972
# L1_loss:0.1461
# Discriminator_loss:0.4861
#
# EPOCH[21] - STEP[100]
# Generator_loss:4.7837
# L1_loss:0.1604
# Discriminator_loss:0.1588
#
# EPOCH[21] - STEP[200]
# Generator_loss:3.4433
# L1_loss:0.1472
# Discriminator_loss:0.3571
#
# EPOCH[22] - STEP[100]
# Generator_loss:5.1340
# L1_loss:0.1482
# Discriminator_loss:0.0933
#
# EPOCH[22] - STEP[200]
# Generator_loss:1.1606
# L1_loss:0.1666
# Discriminator_loss:0.5832
#
# EPOCH[23] - STEP[100]
# Generator_loss:5.1076
# L1_loss:0.1184
# Discriminator_loss:0.5608
#
# EPOCH[23] - STEP[200]
# Generator_loss:4.0882
# L1_loss:0.1144
# Discriminator_loss:2.5176
#
# EPOCH[24] - STEP[100]
# Generator_loss:2.6936
# L1_loss:0.1401
# Discriminator_loss:0.1773
#
# EPOCH[24] - STEP[200]
# Generator_loss:3.0980
# L1_loss:0.1126
# Discriminator_loss:0.2733
#
# EPOCH[25] - STEP[100]
# Generator_loss:4.3445
# L1_loss:0.1259
# Discriminator_loss:0.5566
#
# EPOCH[25] - STEP[200]
# Generator_loss:2.4097
# L1_loss:0.1429
# Discriminator_loss:0.3566
#
# EPOCH[26] - STEP[100]
# Generator_loss:1.9272
# L1_loss:0.1377
# Discriminator_loss:0.5331
#
# EPOCH[26] - STEP[200]
# Generator_loss:4.5460
# L1_loss:0.1519
# Discriminator_loss:0.0391
#
# EPOCH[27] - STEP[100]
# Generator_loss:3.3822
# L1_loss:0.1318
# Discriminator_loss:0.4035
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.2464
# L1_loss:0.1417
# Discriminator_loss:0.7728
#
# EPOCH[28] - STEP[100]
# Generator_loss:6.3176
# L1_loss:0.1256
# Discriminator_loss:1.9952
#
# EPOCH[28] - STEP[200]
# Generator_loss:3.5149
# L1_loss:0.1047
# Discriminator_loss:0.7981
#
# EPOCH[29] - STEP[100]
# Generator_loss:0.5460
# L1_loss:0.2060
# Discriminator_loss:1.7065
#
# EPOCH[29] - STEP[200]
# Generator_loss:1.9046
# L1_loss:0.1406
# Discriminator_loss:0.2625
#
# EPOCH[30] - STEP[100]
# Generator_loss:2.6891
# L1_loss:0.1680
# Discriminator_loss:0.1556
#
# EPOCH[30] - STEP[200]
# Generator_loss:4.7408
# L1_loss:0.1289
# Discriminator_loss:0.1296
#
# EPOCH[31] - STEP[100]
# Generator_loss:2.9545
# L1_loss:0.1431
# Discriminator_loss:0.2369
#
# EPOCH[31] - STEP[200]
# Generator_loss:2.8397
# L1_loss:0.1150
# Discriminator_loss:0.2219
#
# EPOCH[32] - STEP[100]
# Generator_loss:2.8764
# L1_loss:0.1474
# Discriminator_loss:0.1399
#
# EPOCH[32] - STEP[200]
# Generator_loss:1.4106
# L1_loss:0.1375
# Discriminator_loss:0.5745
#
# EPOCH[33] - STEP[100]
# Generator_loss:4.2409
# L1_loss:0.1772
# Discriminator_loss:0.0740
#
# EPOCH[33] - STEP[200]
# Generator_loss:3.4812
# L1_loss:0.1081
# Discriminator_loss:0.2836
#
# EPOCH[34] - STEP[100]
# Generator_loss:4.6975
# L1_loss:0.1206
# Discriminator_loss:1.5516
#
# EPOCH[34] - STEP[200]
# Generator_loss:4.0699
# L1_loss:0.1372
# Discriminator_loss:0.2387
#
# EPOCH[35] - STEP[100]
# Generator_loss:1.9373
# L1_loss:0.1202
# Discriminator_loss:0.5548
#
# EPOCH[35] - STEP[200]
# Generator_loss:2.5406
# L1_loss:0.1168
# Discriminator_loss:0.2951
#
# EPOCH[36] - STEP[100]
# Generator_loss:2.8868
# L1_loss:0.1457
# Discriminator_loss:0.2167
#
# EPOCH[36] - STEP[200]
# Generator_loss:3.7726
# L1_loss:0.1509
# Discriminator_loss:0.4688
#
# EPOCH[37] - STEP[100]
# Generator_loss:4.2892
# L1_loss:0.1172
# Discriminator_loss:0.1875
#
# EPOCH[37] - STEP[200]
# Generator_loss:1.9146
# L1_loss:0.1291
# Discriminator_loss:0.3444
#
# EPOCH[38] - STEP[100]
# Generator_loss:3.2963
# L1_loss:0.1266
# Discriminator_loss:0.1206
#
# EPOCH[38] - STEP[200]
# Generator_loss:1.6534
# L1_loss:0.1552
# Discriminator_loss:0.3777
#
# EPOCH[39] - STEP[100]
# Generator_loss:3.4938
# L1_loss:0.1244
# Discriminator_loss:0.2555
#
# EPOCH[39] - STEP[200]
# Generator_loss:3.0758
# L1_loss:0.1990
# Discriminator_loss:0.1413
#
# EPOCH[40] - STEP[100]
# Generator_loss:5.2094
# L1_loss:0.1417
# Discriminator_loss:0.4822
#
# EPOCH[40] - STEP[200]
# Generator_loss:4.5343
# L1_loss:0.1415
# Discriminator_loss:0.1694
#
# EPOCH[41] - STEP[100]
# Generator_loss:3.1327
# L1_loss:0.1351
# Discriminator_loss:0.2424
#
# EPOCH[41] - STEP[200]
# Generator_loss:2.3276
# L1_loss:0.1565
# Discriminator_loss:0.2383
#
# EPOCH[42] - STEP[100]
# Generator_loss:2.3277
# L1_loss:0.1195
# Discriminator_loss:0.4453
#
# EPOCH[42] - STEP[200]
# Generator_loss:3.5506
# L1_loss:0.1108
# Discriminator_loss:0.5153
#
# EPOCH[43] - STEP[100]
# Generator_loss:2.0130
# L1_loss:0.1391
# Discriminator_loss:1.1939
#
# EPOCH[43] - STEP[200]
# Generator_loss:1.2004
# L1_loss:0.1622
# Discriminator_loss:0.7637
#
# EPOCH[44] - STEP[100]
# Generator_loss:4.6164
# L1_loss:0.1479
# Discriminator_loss:0.4009
#
# EPOCH[44] - STEP[200]
# Generator_loss:3.0937
# L1_loss:0.0971
# Discriminator_loss:0.7014
#
# EPOCH[45] - STEP[100]
# Generator_loss:4.3091
# L1_loss:0.1221
# Discriminator_loss:0.6872
#
# EPOCH[45] - STEP[200]
# Generator_loss:3.0202
# L1_loss:0.1501
# Discriminator_loss:0.1874
#
# EPOCH[46] - STEP[100]
# Generator_loss:5.1774
# L1_loss:0.1091
# Discriminator_loss:0.6210
#
# EPOCH[46] - STEP[200]
# Generator_loss:3.8425
# L1_loss:0.1694
# Discriminator_loss:0.1873
#
# EPOCH[47] - STEP[100]
# Generator_loss:2.6036
# L1_loss:0.1094
# Discriminator_loss:0.2560
#
# EPOCH[47] - STEP[200]
# Generator_loss:0.5432
# L1_loss:0.1323
# Discriminator_loss:1.4877
#
# EPOCH[48] - STEP[100]
# Generator_loss:0.7856
# L1_loss:0.1298
# Discriminator_loss:0.8568
#
# EPOCH[48] - STEP[200]
# Generator_loss:5.1970
# L1_loss:0.1049
# Discriminator_loss:1.3758
#
# EPOCH[49] - STEP[100]
# Generator_loss:4.5963
# L1_loss:0.1642
# Discriminator_loss:0.0275
#
# EPOCH[49] - STEP[200]
# Generator_loss:5.5232
# L1_loss:0.1190
# Discriminator_loss:0.0987
#
# EPOCH[50] - STEP[100]
# Generator_loss:5.8096
# L1_loss:0.1488
# Discriminator_loss:0.1659
#
# EPOCH[50] - STEP[200]
# Generator_loss:2.5452
# L1_loss:0.1160
# Discriminator_loss:0.5188
#
# EPOCH[51] - STEP[100]
# Generator_loss:4.8611
# L1_loss:0.1472
# Discriminator_loss:0.0509
#
# EPOCH[51] - STEP[200]
# Generator_loss:3.9753
# L1_loss:0.1175
# Discriminator_loss:0.3472
#
# EPOCH[52] - STEP[100]
# Generator_loss:5.1240
# L1_loss:0.1745
# Discriminator_loss:0.1419
#
# EPOCH[52] - STEP[200]
# Generator_loss:4.9204
# L1_loss:0.1513
# Discriminator_loss:0.3884
#
# EPOCH[53] - STEP[100]
# Generator_loss:4.4314
# L1_loss:0.1590
# Discriminator_loss:0.1497
#
# EPOCH[53] - STEP[200]
# Generator_loss:5.1086
# L1_loss:0.1295
# Discriminator_loss:0.0293
#
# EPOCH[54] - STEP[100]
# Generator_loss:4.2692
# L1_loss:0.1205
# Discriminator_loss:0.0509
#
# EPOCH[54] - STEP[200]
# Generator_loss:2.5868
# L1_loss:0.1256
# Discriminator_loss:0.1870
#
# EPOCH[55] - STEP[100]
# Generator_loss:4.5740
# L1_loss:0.1592
# Discriminator_loss:0.1690
#
# EPOCH[55] - STEP[200]
# Generator_loss:5.6885
# L1_loss:0.1402
# Discriminator_loss:0.2596
#
# EPOCH[56] - STEP[100]
# Generator_loss:0.5945
# L1_loss:0.1275
# Discriminator_loss:1.5686
#
# EPOCH[56] - STEP[200]
# Generator_loss:2.8290
# L1_loss:0.1107
# Discriminator_loss:0.5374
#
# EPOCH[57] - STEP[100]
# Generator_loss:2.5536
# L1_loss:0.1647
# Discriminator_loss:1.0328
#
# EPOCH[57] - STEP[200]
# Generator_loss:4.5585
# L1_loss:0.1152
# Discriminator_loss:0.0560
#
# EPOCH[58] - STEP[100]
# Generator_loss:3.9802
# L1_loss:0.1213
# Discriminator_loss:0.1807
#
# EPOCH[58] - STEP[200]
# Generator_loss:5.7867
# L1_loss:0.1279
# Discriminator_loss:1.2673
#
# EPOCH[59] - STEP[100]
# Generator_loss:3.3207
# L1_loss:0.1279
# Discriminator_loss:0.0911
#
# EPOCH[59] - STEP[200]
# Generator_loss:3.8646
# L1_loss:0.1426
# Discriminator_loss:0.0804
#
# EPOCH[60] - STEP[100]
# Generator_loss:3.8531
# L1_loss:0.1162
# Discriminator_loss:0.1407
#
# EPOCH[60] - STEP[200]
# Generator_loss:4.0933
# L1_loss:0.1039
# Discriminator_loss:0.2633
#
# EPOCH[61] - STEP[100]
# Generator_loss:2.3594
# L1_loss:0.1423
# Discriminator_loss:0.2197
#
# EPOCH[61] - STEP[200]
# Generator_loss:1.3243
# L1_loss:0.1555
# Discriminator_loss:0.6606
#
# EPOCH[62] - STEP[100]
# Generator_loss:2.2697
# L1_loss:0.1332
# Discriminator_loss:0.6423
#
# EPOCH[62] - STEP[200]
# Generator_loss:2.9445
# L1_loss:0.1162
# Discriminator_loss:0.1140
#
# EPOCH[63] - STEP[100]
# Generator_loss:0.9860
# L1_loss:0.1263
# Discriminator_loss:0.7750
#
# EPOCH[63] - STEP[200]
# Generator_loss:2.6597
# L1_loss:0.1104
# Discriminator_loss:0.1647
#
# EPOCH[64] - STEP[100]
# Generator_loss:5.1885
# L1_loss:0.0997
# Discriminator_loss:0.0800
#
# EPOCH[64] - STEP[200]
# Generator_loss:4.5152
# L1_loss:0.1476
# Discriminator_loss:0.0471
#
# EPOCH[65] - STEP[100]
# Generator_loss:5.3621
# L1_loss:0.1269
# Discriminator_loss:0.6316
#
# EPOCH[65] - STEP[200]
# Generator_loss:4.9868
# L1_loss:0.1191
# Discriminator_loss:0.1008
#
# EPOCH[66] - STEP[100]
# Generator_loss:3.3974
# L1_loss:0.1228
# Discriminator_loss:0.2825
#
# EPOCH[66] - STEP[200]
# Generator_loss:7.3587
# L1_loss:0.1474
# Discriminator_loss:0.0322
#
# EPOCH[67] - STEP[100]
# Generator_loss:4.0764
# L1_loss:0.1192
# Discriminator_loss:0.1510
#
# EPOCH[67] - STEP[200]
# Generator_loss:0.4497
# L1_loss:0.1236
# Discriminator_loss:1.3757
#
# EPOCH[68] - STEP[100]
# Generator_loss:5.4849
# L1_loss:0.1102
# Discriminator_loss:1.8838
#
# EPOCH[68] - STEP[200]
# Generator_loss:4.7315
# L1_loss:0.1372
# Discriminator_loss:0.0767
#
# EPOCH[69] - STEP[100]
# Generator_loss:3.4011
# L1_loss:0.0930
# Discriminator_loss:1.3013
#
# EPOCH[69] - STEP[200]
# Generator_loss:2.6641
# L1_loss:0.1431
# Discriminator_loss:0.1806
#
# EPOCH[70] - STEP[100]
# Generator_loss:3.2124
# L1_loss:0.1033
# Discriminator_loss:0.1957
#
# EPOCH[70] - STEP[200]
# Generator_loss:1.4598
# L1_loss:0.1230
# Discriminator_loss:0.5138
#
# EPOCH[71] - STEP[100]
# Generator_loss:1.4802
# L1_loss:0.1083
# Discriminator_loss:0.4693
#
# EPOCH[71] - STEP[200]
# Generator_loss:4.2251
# L1_loss:0.1451
# Discriminator_loss:0.2753
#
# EPOCH[72] - STEP[100]
# Generator_loss:1.5639
# L1_loss:0.1381
# Discriminator_loss:0.5874
#
# EPOCH[72] - STEP[200]
# Generator_loss:2.6470
# L1_loss:0.1320
# Discriminator_loss:0.1755
#
# EPOCH[73] - STEP[100]
# Generator_loss:6.7652
# L1_loss:0.1471
# Discriminator_loss:0.6295
#
# EPOCH[73] - STEP[200]
# Generator_loss:4.8267
# L1_loss:0.1313
# Discriminator_loss:0.0647
#
# EPOCH[74] - STEP[100]
# Generator_loss:6.3289
# L1_loss:0.1148
# Discriminator_loss:0.3645
#
# EPOCH[74] - STEP[200]
# Generator_loss:2.1023
# L1_loss:0.1432
# Discriminator_loss:0.1931
#
# EPOCH[75] - STEP[100]
# Generator_loss:2.1674
# L1_loss:0.1177
# Discriminator_loss:0.3009
#
# EPOCH[75] - STEP[200]
# Generator_loss:3.9347
# L1_loss:0.1230
# Discriminator_loss:0.0518
#
# EPOCH[76] - STEP[100]
# Generator_loss:2.2026
# L1_loss:0.1265
# Discriminator_loss:0.2549
#
# EPOCH[76] - STEP[200]
# Generator_loss:8.2032
# L1_loss:0.1532
# Discriminator_loss:0.0625
#
# EPOCH[77] - STEP[100]
# Generator_loss:4.6101
# L1_loss:0.1079
# Discriminator_loss:0.0430
#
# EPOCH[77] - STEP[200]
# Generator_loss:4.5556
# L1_loss:0.1271
# Discriminator_loss:0.1447
#
# EPOCH[78] - STEP[100]
# Generator_loss:4.2037
# L1_loss:0.1891
# Discriminator_loss:0.0387
#
# EPOCH[78] - STEP[200]
# Generator_loss:6.7875
# L1_loss:0.1682
# Discriminator_loss:0.0254
#
# EPOCH[79] - STEP[100]
# Generator_loss:4.4973
# L1_loss:0.1104
# Discriminator_loss:0.0804
#
# EPOCH[79] - STEP[200]
# Generator_loss:2.8137
# L1_loss:0.1062
# Discriminator_loss:0.2048
#
# EPOCH[80] - STEP[100]
# Generator_loss:3.8177
# L1_loss:0.1089
# Discriminator_loss:0.1317
#
# EPOCH[80] - STEP[200]
# Generator_loss:3.3726
# L1_loss:0.1229
# Discriminator_loss:0.7053
#
# EPOCH[81] - STEP[100]
# Generator_loss:4.0199
# L1_loss:0.1250
# Discriminator_loss:0.0567
#
# EPOCH[81] - STEP[200]
# Generator_loss:2.6565
# L1_loss:0.1222
# Discriminator_loss:0.1976
#
# EPOCH[82] - STEP[100]
# Generator_loss:3.0017
# L1_loss:0.1093
# Discriminator_loss:0.0962
#
# EPOCH[82] - STEP[200]
# Generator_loss:4.2698
# L1_loss:0.1448
# Discriminator_loss:0.1761
#
# EPOCH[83] - STEP[100]
# Generator_loss:5.6970
# L1_loss:0.1283
# Discriminator_loss:0.4450
#
# EPOCH[83] - STEP[200]
# Generator_loss:2.3595
# L1_loss:0.1220
# Discriminator_loss:0.3067
#
# EPOCH[84] - STEP[100]
# Generator_loss:4.1098
# L1_loss:0.1554
# Discriminator_loss:0.0634
#
# EPOCH[84] - STEP[200]
# Generator_loss:3.0375
# L1_loss:0.1424
# Discriminator_loss:0.1332
#
# EPOCH[85] - STEP[100]
# Generator_loss:1.8671
# L1_loss:0.1126
# Discriminator_loss:0.2999
#
# EPOCH[85] - STEP[200]
# Generator_loss:4.8050
# L1_loss:0.1326
# Discriminator_loss:0.0571
#
# EPOCH[86] - STEP[100]
# Generator_loss:6.3374
# L1_loss:0.1301
# Discriminator_loss:0.1945
#
# EPOCH[86] - STEP[200]
# Generator_loss:3.3972
# L1_loss:0.1052
# Discriminator_loss:0.1096
#
# EPOCH[87] - STEP[100]
# Generator_loss:2.0821
# L1_loss:0.1198
# Discriminator_loss:0.2962
#
# EPOCH[87] - STEP[200]
# Generator_loss:3.5322
# L1_loss:0.1134
# Discriminator_loss:0.0812
#
# EPOCH[88] - STEP[100]
# Generator_loss:3.1281
# L1_loss:0.1141
# Discriminator_loss:0.4687
#
# EPOCH[88] - STEP[200]
# Generator_loss:3.1524
# L1_loss:0.1244
# Discriminator_loss:0.2234
#
# EPOCH[89] - STEP[100]
# Generator_loss:2.4092
# L1_loss:0.1304
# Discriminator_loss:0.2823
#
# EPOCH[89] - STEP[200]
# Generator_loss:4.1725
# L1_loss:0.1187
# Discriminator_loss:0.0462
#
# EPOCH[90] - STEP[100]
# Generator_loss:2.7276
# L1_loss:0.1665
# Discriminator_loss:0.2844
#
# EPOCH[90] - STEP[200]
# Generator_loss:5.0783
# L1_loss:0.1250
# Discriminator_loss:0.0538
#
# EPOCH[91] - STEP[100]
# Generator_loss:6.8820
# L1_loss:0.1179
# Discriminator_loss:0.0677
#
# EPOCH[91] - STEP[200]
# Generator_loss:4.6543
# L1_loss:0.1682
# Discriminator_loss:0.1168
#
# EPOCH[92] - STEP[100]
# Generator_loss:3.4594
# L1_loss:0.1709
# Discriminator_loss:0.0663
#
# EPOCH[92] - STEP[200]
# Generator_loss:8.6002
# L1_loss:0.1117
# Discriminator_loss:0.0452
#
# EPOCH[93] - STEP[100]
# Generator_loss:6.8089
# L1_loss:0.1064
# Discriminator_loss:0.0626
#
# EPOCH[93] - STEP[200]
# Generator_loss:5.2845
# L1_loss:0.1365
# Discriminator_loss:0.8592
#
# EPOCH[94] - STEP[100]
# Generator_loss:1.2065
# L1_loss:0.1301
# Discriminator_loss:0.6514
#
# EPOCH[94] - STEP[200]
# Generator_loss:2.4644
# L1_loss:0.1446
# Discriminator_loss:0.3039
#
# EPOCH[95] - STEP[100]
# Generator_loss:4.2405
# L1_loss:0.1122
# Discriminator_loss:0.3233
#
# EPOCH[95] - STEP[200]
# Generator_loss:5.3593
# L1_loss:0.1311
# Discriminator_loss:0.2766
#
# EPOCH[96] - STEP[100]
# Generator_loss:6.8921
# L1_loss:0.1442
# Discriminator_loss:0.0226
#
# EPOCH[96] - STEP[200]
# Generator_loss:3.8027
# L1_loss:0.1550
# Discriminator_loss:0.0528
#
# EPOCH[97] - STEP[100]
# Generator_loss:1.0501
# L1_loss:0.1464
# Discriminator_loss:0.6942
#
# EPOCH[97] - STEP[200]
# Generator_loss:4.3959
# L1_loss:0.1088
# Discriminator_loss:0.3310
#
# EPOCH[98] - STEP[100]
# Generator_loss:3.4781
# L1_loss:0.1002
# Discriminator_loss:0.2377
#
# EPOCH[98] - STEP[200]
# Generator_loss:3.8748
# L1_loss:0.1416
# Discriminator_loss:0.4066
#
# EPOCH[99] - STEP[100]
# Generator_loss:0.5927
# L1_loss:0.1240
# Discriminator_loss:1.1480
#
# EPOCH[99] - STEP[200]
# Generator_loss:3.6055
# L1_loss:0.1354
# Discriminator_loss:0.3640
#
# EPOCH[100] - STEP[100]
# Generator_loss:5.7565
# L1_loss:0.1344
# Discriminator_loss:0.3637
#
# EPOCH[100] - STEP[200]
# Generator_loss:1.8525
# L1_loss:0.1176
# Discriminator_loss:0.4475

# %%
plt.figure(figsize=(16,10))

plt.subplot(311)
plt.plot(history['gen_loss'])
plt.title('Generator Loss')

plt.subplot(312)
plt.plot(history['l1_loss'])
plt.title('L1 Loss')

plt.subplot(313)
plt.plot(history['disc_loss'])
plt.title('Discriminator Loss')

plt.show()

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator2(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# # 회고
#
# 노드에는 10번이라 50번 100번으로 돌려보았지만 잘 나오지 않았고 훨씬더 많은 에퐄을 돌려야 잘나올거같음 50 차이 이긴 하지만 변화하는걸 눈으로 확인할수 있는거같다. 어떤식으로 더 많이 나눠서 돌려보면 어떤색으로 점점 변해가는지 파악할수 있을거같음
